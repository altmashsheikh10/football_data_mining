# %% [markdown]
# # **Football Teams Rating**

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the Data

# %%
df = pd.read_csv('football_teams.csv')
df
# Out:
#                    Team      Tournament  Goals  Shots pg  yellow_cards  \
# 0       Manchester City  Premier League     83      15.8            46
# 1         Bayern Munich      Bundesliga     99      17.1            44
# 2   Paris Saint-Germain         Ligue 1     86      15.0            73
# 3             Barcelona          LaLiga     85      15.3            68
# 4           Real Madrid          LaLiga     67      14.4            57
# ..                  ...             ...    ...       ...           ...
# 93     Sheffield United  Premier League     20       8.5            73
# 94              Crotone         Serie A     45       9.5            85
# 95            Benevento         Serie A     40      11.0            90
# 96                Dijon         Ligue 1     25       9.2            75
# 97           Schalke 04      Bundesliga     25       8.9            70
#
#     red_cards  Possession%  Pass%  AerialsWon  Rating
# 0           2         60.8   89.4        12.8    7.01
# 1           3         58.1   85.5        12.9    6.95
# 2           7         60.1   89.5         9.5    6.88
# 3           2         62.4   89.7        10.6    6.87
# 4           2         57.7   87.7        11.8    6.86
# ..        ...          ...    ...         ...     ...
# 93          3         43.0   76.9        19.1    6.46
# 94          4         47.2   80.4        12.7    6.43
# 95          5         44.2   77.7        13.4    6.43
# 96          5         46.9   80.0        14.3    6.42
# 97          2         46.2   76.5        15.6    6.41
#
# [98 rows x 10 columns]

# %% [markdown]
# # Understanding the Data

# %%
df.dtypes
# Out:
# Team             object
# Tournament       object
# Goals             int64
# Shots pg        float64
# yellow_cards      int64
# red_cards         int64
# Possession%     float64
# Pass%           float64
# AerialsWon      float64
# Rating          float64
# dtype: object

# %%
df.shape
# Out:
# (98, 10)

# %%
df.size
# Out:
# 980

# %%
df.columns
# Out:
# Index(['Team', 'Tournament', 'Goals', 'Shots pg', 'yellow_cards', 'red_cards',
#        'Possession%', 'Pass%', 'AerialsWon', 'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          98 non-null     object
#  1   Tournament    98 non-null     object
#  2   Goals         98 non-null     int64
#  3   Shots pg      98 non-null     float64
#  4   yellow_cards  98 non-null     int64
#  5   red_cards     98 non-null     int64
#  6   Possession%   98 non-null     float64
#  7   Pass%         98 non-null     float64
#  8   AerialsWon    98 non-null     float64
#  9   Rating        98 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.8+ KB

# %%
df.describe()
# Out:
#            Goals   Shots pg  yellow_cards  red_cards  Possession%      Pass%  \
# count  98.000000  98.000000     98.000000  98.000000    98.000000  98.000000
# mean   52.183673  11.851020     69.704082   3.336735    49.995918  80.441837
# std    16.445691   2.149718     15.137316   2.148814     4.890068   4.690172
# min    20.000000   7.100000     40.000000   0.000000    38.500000  66.500000
# 25%    40.250000  10.325000     60.000000   2.000000    46.225000  78.025000
# 50%    50.000000  11.450000     67.500000   3.000000    49.750000  80.800000
# 75%    61.750000  13.350000     80.000000   4.750000    52.850000  83.450000
# max    99.000000  17.100000    117.000000  10.000000    62.400000  89.700000
#
#        AerialsWon     Rating
# count   98.000000  98.000000
# mean    16.006122   6.646122
# std      3.078955   0.132148
# min      9.500000   6.410000
# 25%     14.025000   6.540000
# 50%     16.100000   6.630000
# 75%     17.850000   6.730000
# max     26.800000   7.010000

# %%
df.corr(numeric_only=True)
# Out:
#                  Goals  Shots pg  yellow_cards  red_cards  Possession%  \
# Goals         1.000000  0.829698     -0.189157  -0.001185     0.717834
# Shots pg      0.829698  1.000000     -0.369343  -0.105080     0.759153
# yellow_cards -0.189157 -0.369343      1.000000   0.368847    -0.164302
# red_cards    -0.001185 -0.105080      0.368847   1.000000    -0.083360
# Possession%   0.717834  0.759153     -0.164302  -0.083360     1.000000
# Pass%         0.694214  0.684035     -0.184238  -0.043761     0.851458
# AerialsWon   -0.495579 -0.382147      0.060116  -0.031791    -0.543970
# Rating        0.852152  0.851265     -0.417049  -0.162358     0.734978
#
#                  Pass%  AerialsWon    Rating
# Goals         0.694214   -0.495579  0.852152
# Shots pg      0.684035   -0.382147  0.851265
# yellow_cards -0.184238    0.060116 -0.417049
# red_cards    -0.043761   -0.031791 -0.162358
# Possession%   0.851458   -0.543970  0.734978
# Pass%         1.000000   -0.764788  0.668573
# AerialsWon   -0.764788    1.000000 -0.327225
# Rating        0.668573   -0.327225  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(numeric_only=True), yticklabels='auto', annot=False, cmap='YlGnBu')
plt.show()

# %%
df.nunique()
# Out:
# Team            98
# Tournament       5
# Goals           49
# Shots pg        61
# yellow_cards    53
# red_cards       11
# Possession%     80
# Pass%           75
# AerialsWon      62
# Rating          43
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Team            0
# Tournament      0
# Goals           0
# Shots pg        0
# yellow_cards    0
# red_cards       0
# Possession%     0
# Pass%           0
# AerialsWon      0
# Rating          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(10,6))
colors = sns.color_palette('bright')
df1 = df['Tournament'].value_counts()
plt.pie(df1.values, labels=df1.index, autopct='%0.2f%%', startangle=90, colors=colors, shadow=True, wedgeprops={'linewidth':0.5, 'edgecolor':'white'})
plt.title('Percentage of teams by League', fontsize=15)
plt.show()

# %%
sns.set_style('ticks')
plt.figure(figsize=(18,8))
sns.barplot(x='Team',y='Goals', data=df[:10].sort_values(by='Goals',ascending=False), palette='bright')
plt.title('Top 10 Goal Scoring Teams', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x=df.Tournament, y=df.Goals, palette='bright')
plt.xlabel("League")
plt.title("Number of Goals scored per team by League")
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=df.Tournament, y=df.Goals, palette='bright')
plt.xlabel("League")
plt.title('Goals per League', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Team',y='Possession%',data=df[:10].sort_values(by='Possession%',ascending=False),palette='rainbow')
plt.title("Top Possession Teams are", fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(x='Pass%',data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(x='Possession%',data=df, color='r')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(x='AerialsWon',data=df, color='g')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['red_cards'], color='red', kde=True, alpha=0.3)
plt.xlabel('Number of Red Cards')
plt.title('Density plot of red cards by team', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['yellow_cards'], color='yellow', kde=True, alpha=0.3)
plt.xlabel('Number of Yellow Cards')
plt.title('Density plot of yellow cards by team', fontsize=15)
plt.show()

# %%
sns.set_style('ticks')
plt.figure(figsize=(18,8))
sns.barplot(x='Team',y='Rating', data=df[:10].sort_values(by='Rating',ascending=False), palette='bright')
plt.title('Top 10 Teams by Rating', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Top 10 Teams by Rating')

# %%
plt.figure(figsize=(18,8))
sns.pairplot(df, height=1.5, hue='Tournament')
plt.show()

# %% [markdown]
# # Splitting the Data into Dependent and Independent Variables

# %%
x = df.drop(['Team', 'Tournament' ,'Rating'], axis=1)
y = df["Rating"]

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.39058393 0.31746773 0.05505697 0.02976527 0.10824377 0.06448729
#  0.03439506]

# %%
feat_imp = pd.Series(model.feature_importances_, index=x.columns)
feat_imp.nlargest(5).plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Training and Testing the Data

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=10)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction

# %%
ypred_train = lr.predict(xtrain)
ypred_test = lr.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac1 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac1)
# Out:
# Accuracy of training data: 85.937156355181
# Accuracy of testing data: 85.50910152456672

# %% [markdown]
# ## Error

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ytest, ypred_test))
print('Mean Squared Error:', metrics.mean_squared_error(ytest, ypred_test))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ytest, ypred_test)))
# Out:
# Mean Absolute Error: 0.04347097831344247
# Mean Squared Error: 0.002554564264987948
# Root Mean Squared Error: 0.050542697444714485

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %% [markdown]
# ## Prediction

# %%
ypred_train = knn.predict(xtrain)
ypred_test = knn.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac2 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac2)
# Out:
# Accuracy of training data: 84.2542613795557
# Accuracy of testing data: 89.04882333939983

# %% [markdown]
# ## Error

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ytest, ypred_test))
print('Mean Squared Error:', metrics.mean_squared_error(ytest, ypred_test))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ytest, ypred_test)))
# Out:
# Mean Absolute Error: 0.036833333333333315
# Mean Squared Error: 0.001930555555555554
# Root Mean Squared Error: 0.04393808775488021

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=3, n_jobs=1)
rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(max_depth=3, n_jobs=1)

# %% [markdown]
# ## Prediction

# %%
ypred_train = rf.predict(xtrain)
ypred_test = rf.predict(xtest)

# %% [markdown]
# ## Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac3 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac3)
# Out:
# Accuracy of training data: 90.14203272198176
# Accuracy of testing data: 79.16657619382347

# %% [markdown]
# ## Error

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(ytest, ypred_test))
print('Mean Squared Error:', metrics.mean_squared_error(ytest, ypred_test))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(ytest, ypred_test)))
# Out:
# Mean Absolute Error: 0.0504624337292086
# Mean Squared Error: 0.00367267219923135
# Root Mean Squared Error: 0.06060257584650466

# %% [markdown]
# # Comparing Accuracy

# %%
accuracy =  {ac1: 'Logistic Regression', ac2: 'KNN', ac3:'Random Forest'}

# %%
sns.set_style('ticks')
plt.figure(figsize=(14, 8))
model_accuracies = list(accuracy.values())
model_names = list(accuracy.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='bright')
# Out:
# <Axes: >

# %% [markdown]
# As accuracy of **KNN Regressor** algorithm is more ie. **89.04%**
#
# Hence we will save the model.

# %% [markdown]
# # Saving the Model

# %%
import pickle
pickle.dump(knn, open('model.pkl', 'wb'))

# %% [markdown]
# # Sample Prediction

# %%
p = model.predict([[67,	14.4,	57,	2,	57.7,	87.7,	11.8]])
print("Rating = ", round(float(p),2))
# Out:
# Rating =  6.86
